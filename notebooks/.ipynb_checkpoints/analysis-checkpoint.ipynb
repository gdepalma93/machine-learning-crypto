# %%
import pandas as pd
# Initial Imports
from pathlib import Path
from dotenv import load_dotenv

csv_path = Path("/Users/gdepa/PyCharmProjects/ghost/fintech-apps/ml-research/data-analysis")/'btc_df.csv'
btc_df = pd.DataFrame()
btc_df = pd.read_csv(csv_path)

btc_df.set_index('x',inplace=True)
btc_df.head()
# Out:
#             market-price  trade-volume_x  trade-volume_y  hash-rate  \
# x
# 2012-04-01          4.94             0.0             0.0  12.128462
# 2012-04-02          4.97             0.0             0.0  10.268764
# 2012-04-03          5.06             0.0             0.0  10.349621
# 2012-04-04          5.00             0.0             0.0  11.400754
# 2012-04-05          4.96             0.0             0.0   9.621913
#
#             transaction-fees-usd  n-unique-addresses  n-transactions  \
# x
# 2012-04-01             20.672928              9862.0          5563.0
# 2012-04-02             27.873555             11210.0          6472.0
# 2012-04-03             28.287519             13314.0          7739.0
# 2012-04-04             25.797735             12518.0          7143.0
# 2012-04-05             25.046747             12119.0          7028.0
#
#             mempool-count  n-transactions-excluding-popular
# x
# 2012-04-01            NaN                            5563.0
# 2012-04-02            NaN                            6472.0
# 2012-04-03            NaN                            7739.0
# 2012-04-04            NaN                            7143.0
# 2012-04-05            NaN                            7028.0

# %%
btc_df.isna().sum()
# Out:
# market-price                           0
# trade-volume_x                         0
# trade-volume_y                         0
# hash-rate                              1
# transaction-fees-usd                   1
# n-unique-addresses                    10
# n-transactions                         1
# mempool-count                       1536
# n-transactions-excluding-popular       1
# dtype: int64

# %%
recent_df = btc_df.dropna()
recent_df.head()
# Out:
#             market-price  trade-volume_x  trade-volume_y     hash-rate  \
# x
# 2016-06-15        685.19    7.278986e+06    7.278986e+06  1.500925e+06
# 2016-06-16        693.88    4.007337e+06    4.007337e+06  1.452194e+06
# 2016-06-17        765.00    1.372351e+07    1.372351e+07  1.452194e+06
# 2016-06-18        746.63    1.098315e+07    1.098315e+07  1.549656e+06
# 2016-06-19        751.96    4.438797e+06    4.438797e+06  1.725089e+06
#
#             transaction-fees-usd  n-unique-addresses  n-transactions  \
# x
# 2016-06-15          57175.506545            456788.0        259202.0
# 2016-06-16          62188.548755            472980.0        267870.0
# 2016-06-17          60036.816514            456749.0        253752.0
# 2016-06-18          53013.092584            425975.0        235317.0
# 2016-06-19          48075.431449            415726.0        218298.0
#
#             mempool-count  n-transactions-excluding-popular
# x
# 2016-06-15      16912.250                          255542.0
# 2016-06-16      11521.125                          263444.0
# 2016-06-17       8816.250                          250428.0
# 2016-06-18       8055.750                          232850.0
# 2016-06-19       3621.750                          215405.0

# %% [markdown]
# ***Plot Data***

# %%
# PLOT GRAPHS OF ALL FEATURE DATA
from matplotlib import pyplot
dataset = btc_df
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5, 6, 7, 8]
i = 1
# plot each column
pyplot.figure(figsize=(16, 48), dpi=120)
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=0.5, loc='center')
    i += 1
pyplot.savefig('totalled_df.png')
pyplot.show()

# %%
# CALCULATE AMOUNT OF MISSING DATA
NaN_by_column = btc_df.isnull().sum(axis=0).tolist()
print("Missing Data Elements")
print(NaN_by_column)
# Out:
# Missing Data Elements
# [0, 0, 0, 1, 1, 10, 1, 1536, 1]

# %%
# PLOT ALL FEATURE DATA FROM 2016
dataset = recent_df
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5, 6, 7, 8]
i = 1
# plot each column
pyplot.figure(figsize=(16, 48), dpi=120)
for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=0.5, loc='center')
    i += 1
#pyplot.savefig('recent_df.png')
pyplot.show()

# %%
# CREATE ARRAY OF FEATURES
feature_dict = {0: 'market-price', 1: 'trade-volume_x', 2: 'hash-rate', 3: 'transaction-fees-usd', 
     4: 'n-unique-addresses', 5: 'n-transactions', 6: 'mempool-count', 7: 'n-transactions-excluding-popular'}

features = []
for k in feature_dict:
    features.append(recent_df[feature_dict[k]].values)

market_prices = features[0]

# %%
market_prices
# Out:
# array([  685.19,   693.88,   765.  , ..., 19709.73, 18792.52, 19226.97])

# %%
# CALCULATE FEATURE CORRELATION
import numpy as np
from scipy.stats import pearsonr

print("Feature compared with market price {0:9} correlation and p-value for the correlation: {1}".format("", ""))
print()
index = 0
for feature in features:
    output = "Feature: {0:35} correlation: {1}".format(feature_dict[index], pearsonr(market_prices, feature))
    print(output)
    index+=1
# Out:
# Feature compared with market price           correlation and p-value for the correlation:
#
# Feature: market-price                        correlation: (0.9999999999999994, 0.0)
# Feature: trade-volume_x                      correlation: (0.43476154406039774, 3.908072473643168e-76)
# Feature: hash-rate                           correlation: (0.6700763634025837, 5.8277416316250937e-213)
# Feature: transaction-fees-usd                correlation: (0.47481897558603503, 2.0112688072723855e-92)
# Feature: n-unique-addresses                  correlation: (0.5601590102202482, 2.6872537428267978e-135)
# Feature: n-transactions                      correlation: (0.2992385230695952, 4.511020361443963e-35)
# Feature: mempool-count                       correlation: (0.1554357109182792, 2.8082080877184706e-10)
# Feature: n-transactions-excluding-popular    correlation: (0.2810558835394306, 5.681369167558805e-31)

# %%
# PERFORM RANDOM FOREST FEATURE ANALYSIS
from sklearn.ensemble import RandomForestRegressor

names = []
for name in feature_dict.values():
    if name != 'market-price':
        if name != 'trade-volume':
            names.append(name)

X = np.asarray(recent_df)[:,2:] # exclude market price and trade volumme 
Y =  np.asarray(recent_df)[:,1]
rf = RandomForestRegressor()
rf.fit(X, Y)

print ("Features sorted by their score:")
result = sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), 
             reverse=True)
for r in result:
    print(r)
# Out:
# Features sorted by their score:
# (0.9929, 'trade-volume_x')
# (0.0023, 'mempool-count')
# (0.0019, 'transaction-fees-usd')
# (0.0016, 'n-unique-addresses')
# (0.0008, 'n-transactions-excluding-popular')
# (0.0003, 'hash-rate')
# (0.0002, 'n-transactions')

# %%
# SAME RANDOM FOREST ANALYSIS, EXCLUDINNG ALL USD RELATED FEATURES
names = []
for name in feature_dict.values():
    if name != 'market-price':
        if name != 'trade-volume':
            if name != 'transaction-fees-usd':
                names.append(name)

recent_df = recent_df.drop('transaction-fees-usd', 1) # exclude  transaction fees
X = np.asarray(recent_df)[:,2:] # exclude market price and trade volumme 
Y =  np.asarray(recent_df)[:,1]
rf = RandomForestRegressor()
rf.fit(X, Y)

print ("Features sorted by their score:")
print("Excluding all features related to Bitcoin USD price")
result = sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), 
             reverse=True)
for r in result:
    print(r)
# Out:
# Features sorted by their score:
# Excluding all features related to Bitcoin USD price
# (0.9945, 'trade-volume_x')
# (0.0025, 'n-unique-addresses')
# (0.0017, 'mempool-count')
# (0.0006, 'n-transactions-excluding-popular')
# (0.0005, 'hash-rate')
# (0.0003, 'n-transactions')

# %% [markdown]
# ___

# %%
import pandas as pd
import numpy as np
btc_df = pd.read_csv('btc_df.csv')
btc_df
# Out:
#                x  market-price  trade-volume_x  trade-volume_y     hash-rate  \
# 0     2012-04-01          4.94    0.000000e+00    0.000000e+00  1.212846e+01
# 1     2012-04-02          4.97    0.000000e+00    0.000000e+00  1.026876e+01
# 2     2012-04-03          5.06    0.000000e+00    0.000000e+00  1.034962e+01
# 3     2012-04-04          5.00    0.000000e+00    0.000000e+00  1.140075e+01
# 4     2012-04-05          4.96    0.000000e+00    0.000000e+00  9.621913e+00
# ...          ...           ...             ...             ...           ...
# 3165  2020-11-30      18191.60    1.922939e+08    1.922939e+08  1.076107e+08
# 3166  2020-12-01      19709.73    5.704299e+08    5.704299e+08  1.447507e+08
# 3167  2020-12-02      18792.52    5.862289e+08    5.862289e+08  1.247523e+08
# 3168  2020-12-03      19226.97    3.115002e+08    3.115002e+08  1.495123e+08
# 3169  2020-12-04      19454.54    2.698177e+08    2.698177e+08           NaN
#
#       transaction-fees-usd  n-unique-addresses  n-transactions  mempool-count  \
# 0             2.067293e+01              9862.0          5563.0            NaN
# 1             2.787355e+01             11210.0          6472.0            NaN
# 2             2.828752e+01             13314.0          7739.0            NaN
# 3             2.579773e+01             12518.0          7143.0            NaN
# 4             2.504675e+01             12119.0          7028.0            NaN
# ...                    ...                 ...             ...            ...
# 3165          1.377090e+06            623554.0        256551.0       3413.125
# 3166          2.799807e+06            841581.0        378068.0      91610.000
# 3167          2.523414e+06            756978.0        327019.0      54954.875
# 3168          2.817492e+06            777633.0        346921.0      43426.375
# 3169                   NaN                 NaN             NaN      26590.375
#
#       n-transactions-excluding-popular
# 0                               5563.0
# 1                               6472.0
# 2                               7739.0
# 3                               7143.0
# 4                               7028.0
# ...                                ...
# 3165                          253811.0
# 3166                          374601.0
# 3167                          323679.0
# 3168                          343417.0
# 3169                               NaN
#
# [3170 rows x 10 columns]

# %%
data_df = btc_df.copy(deep=True)
prev_price = 0
for i, row in data_df.iterrows():
    change = 0
    if row[0] > prev_price:
        change = 1
    prev_price = row[0]
    data_df.set_value(i-86400,'y',change)
    
data_df = data_df.iloc[:2,:]
data_df = data_df.drop('mempool-count',1)
NaN_by_column = data_df.isnull().sum(axis=0).tolist()
print(NaN_by_column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-bbb043241214> in <module>
#       3 for i, row in data_df.iterrows():
#       4     change = 0
# ----> 5     if row[0] > prev_price:
#       6         change = 1
#       7     prev_price = row[0]
#
# TypeError: '>' not supported between instances of 'str' and 'int'
